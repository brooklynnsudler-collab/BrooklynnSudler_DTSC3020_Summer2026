# %% [markdown]
# <a href="https://colab.research.google.com/github/brooklynnsudler-collab/BrooklynnSudler_DTSC3020_Summer2026/blob/main/Brooklynn_Sudler_FinalExam_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DTSC 3020 — Final Exam
#
# ## Part 2: Practical Coding Section
#
# **Total Points: 120**
#
# ### Instructions
#
# * Open this notebook in Google Colab.
# * Select **File → Save a copy in Drive**.
# * Rename the notebook as:
#   **FirstName_LastName_FinalExam_Part2.ipynb**
# * Complete all questions in the provided code cells.
# * Run all required cells and make sure your code works without errors.
# * Do not change the provided data or instructions.
#
# ### After completing the notebook, do both of the following:
#
# 1. Select **File → Download → Download .ipynb**.
#    The download may not be visible while using Respondus LockDown Browser, but the file should still be saved to your computer.
#
# 2. Select **File → Save a copy in GitHub** and save the notebook to your GitHub repository.
#    You do not need to copy or submit the GitHub link.
#
# After completing all parts of the exam, submit the Final Exam quiz and exit Respondus LockDown Browser. Then return to Canvas using your regular browser and upload your completed Part 2 and Part 3 notebooks to the **Final Exam Notebook Submission – Parts 2 and 3** assignment within **10 minutes**.
#
# Make sure you upload the correct completed Part 2 notebook.

# %% [markdown]
# ## Question 1 — Student Username Generator
#
# **30 points**
#
# Write a Python function named `create_username(first_name, last_name, student_id)`.
#
# The function should create a username using the following rules:
#
# 1. Convert `first_name` and `last_name` to lowercase.
# 2. `student_id` is given as a string.
# 3. Use the **last 3 digits from the right side** of `student_id`.
# 4. Return the username in this format:
#
# ```text
# firstname_lastname_123
# ```
#
# ### Example
#
# ```text
# "Mary", "Watson", "1156723" → mary_watson_723
# ```
#
# In this example, the last 3 digits of `"1156723"` are `"723"`.
#
# Then test your function using this list:
#
# ```python
# students = [
#     ("Mary", "Watson", "1156723"),
#     ("Ali", "Reza", "1234567"),
#     ("Sara", "Amini", "9876543"),
#     ("John", "Smith", "5551298")
# ]
# ```
#
# Print each student’s generated username.
#
# ### Grading — 30 points
#
# | Requirement                                                        | Points |
# | ------------------------------------------------------------------ | -----: |
# | Defines function with correct parameters                           |      6 |
# | Converts first and last name to lowercase                          |      6 |
# | Correctly uses the last 3 digits from the right side of student ID |      6 |
# | Returns username in the correct format                             |      6 |
# | Loops through test data and prints usernames                       |      4 |
# | Code runs without errors                                           |      2 |

# %%
# Question 1

students = [
    ("Mary", "Watson", "1156723"),
    ("Ali", "Reza", "1234567"),
    ("Sara", "Amini", "9876543"),
    ("John", "Smith", "5551298")
]

# creating username sequence
def create_username(first_name, last_name, student_id):
  first_name = first_name.lower()
  last_name = last_name.lower()
  student_id = str(student_id)
  student_id = student_id[4:8]
  return first_name + "_" + last_name + "_" + student_id

# printing student usernames
print(create_username("Mary", "Watson", "1156723"))
print(create_username("Ali", "Reza", "1234567"))
print(create_username("Sara", "Amini", "9876543"))
print(create_username("John", "Smith", "5551298"))
# Out:
# mary_watson_723
# ali_reza_567
# sara_amini_543
# john_smith_298

# %% [markdown]
# ## Question 2 — Online Order Calculator
#
# **30 points**
#
# Write a Python program that calculates the total cost of an online order.
#
# Use this dictionary:
#
# ```python
# prices = {
#     "notebook": 3.50,
#     "pen": 1.25,
#     "backpack": 28.00,
#     "calculator": 15.75,
#     "water bottle": 9.50
# }
# ```
#
# Use this list of customer entries:
#
# ```python
# entries = ["notebook", "pen", "backpack", "laptop", "calculator", "water bottle", "done", "pen"]
# ```
#
# Your program should:
#
# 1. Create an empty list named `cart`.
# 2. Loop through the `entries` list one item at a time.
# 3. If the item is `"done"`, stop the loop.
# 4. Items after `"done"` should be ignored.
# 5. If the item exists in `prices`, add it to `cart` and print a confirmation message.
# 6. If the item does not exist in `prices`, print `"Item not found"`.
# 7. Each valid item counts as **one unit** of that item.
# 8. After the loop stops, calculate:
#
#    * subtotal
#    * discount
#    * final total
#
# ### Discount Rule
#
# * If subtotal is at least `$50`, apply a 10% discount.
# * Otherwise, discount is `$0`.
#
# Print:
#
# * items in the cart
# * subtotal
# * discount
# * final total
#
# Round money values to 2 decimal places when printing.
#
# ### Expected Behavior
#
# The program should:
#
# * add `notebook`, `pen`, `backpack`, `calculator`, and `water bottle` to the cart
# * print `"Item not found"` for `laptop`
# * stop when it reaches `"done"`
# * ignore the final `"pen"` after `"done"`
#
# ### Expected Calculations
#
# ```text
# Subtotal: 58.00
# Discount: 5.80
# Final total: 52.20
# ```
#
# ### Grading — 30 points
#
# | Requirement                                           | Points |
# | ----------------------------------------------------- | -----: |
# | Uses the `prices` dictionary correctly                |      4 |
# | Creates and uses the `cart` list correctly            |      4 |
# | Loops through `entries` and stops at `"done"`         |      6 |
# | Ignores items after `"done"`                          |      3 |
# | Correctly checks whether each item exists in `prices` |      4 |
# | Correctly calculates subtotal                         |      3 |
# | Correctly applies the discount rule                   |      3 |
# | Prints clear output and code runs without errors      |      3 |

# %%
# Question 2

prices = {
    "notebook": 3.50,
    "pen": 1.25,
    "backpack": 28.00,
    "calculator": 15.75,
    "water bottle": 9.50
}

entries = ["notebook", "pen", "backpack", "laptop", "calculator", "water bottle", "done", "pen"]

cart = []

# stops entries list or adds item to cart
for entry in entries:
    if entry == "done":
        break
    if entry in prices:
        cart.append(entry)
        print(f"Added {entry} to cart.")
    else:
        print(f"{entry} not found.")

# calculating subtotal
subtotal = 0
for item in cart:
    subtotal += prices[item]

# applying discount
discount = 0
if subtotal >= 50:
    discount = subtotal * 0.10

final_total = subtotal - discount

# final order summary
print("\n--- Order Summary ---")
print(f"Items in cart: {', '.join(cart)}")
print(f"Subtotal: ${subtotal:.2f}")
print(f"Discount: ${discount:.2f}")
print(f"Final total: ${final_total:.2f}")
# Out:
# Added notebook to cart.
# Added pen to cart.
# Added backpack to cart.
# laptop not found.
# Added calculator to cart.
# Added water bottle to cart.
#
# --- Order Summary ---
# Items in cart: notebook, pen, backpack, calculator, water bottle
# Subtotal: $58.00
# Discount: $5.80
# Final total: $52.20

# %% [markdown]
# ## Question 3 — Study Notes File Summary
#
# **30 points**
#
# You are helping a student summarize their study notes saved in a text file.
#
# Write a Python program that creates a file named `study_notes.txt`, writes several study notes into it, reads the file back, and prints a short summary.
#
# Use this list of notes:
#
# ```python
# notes = [
#     "Python is useful for data science.",
#     "Files can store text data.",
#     "Pandas helps analyze tables.",
#     "Functions make code reusable.",
#     "Errors should be handled carefully."
# ]
# ```
#
# Your program should:
#
# 1. Create a text file named `study_notes.txt`.
#
# 2. Write each note from the `notes` list into the file on a separate line.
#    Add a newline character `"\n"` after each note when writing the file.
#
# 3. Use `try-except` when reading the file.
#
# 4. If the file is read successfully, calculate:
#
#    * total number of lines
#    * total number of words
#    * total number of characters
#
# 5. For the character count, count all characters read from the file, including letters, spaces, punctuation, and newline characters.
#
# 6. Print a clear summary like this:
#
# ```text
# Study Notes Summary
# Total lines:
# Total words:
# Total characters:
# ```
#
# 7. If the file cannot be found when reading, print:
#
# ```text
# File not found.
# ```
#
# The `File not found` branch will usually not run because your program creates the file first. Include it anyway to show exception handling.
#
# ### Grading — 30 points
#
# | Requirement                                       | Points |
# | ------------------------------------------------- | -----: |
# | Creates and writes to `study_notes.txt` correctly |      6 |
# | Reads the file using `try-except`                 |      6 |
# | Counts lines correctly                            |      4 |
# | Counts words correctly                            |      4 |
# | Counts characters correctly                       |      4 |
# | Prints a clear summary                            |      4 |
# | Code runs without errors                          |      2 |

# %%
# Question 3

file_name = "study_notes.txt"

notes = [
    "Python is useful for data science.\n",
    "Files can store text data.\n",
    "Pandas helps analyze tables.\n",
    "Functions make code reusable.\n",
    "Errors should be handled carefully.\n"
]

with open(file_name, "w") as file:
    for note in notes:
      file.write(note)

try:
  with open(file_name, "r") as file:
    lines = file.readlines()
    total_lines = len(lines)
    total_words = sum(len(line.split()) for line in lines)
    total_characters = sum(len(line) for line in lines)

    print("Study Notes Summary")
    print(f"Total lines: {total_lines}")
    print(f"Total words: {total_words}")
    print(f"Total characters: {total_characters}")

  print("\nFile read successfully.")
except FileNotFoundError:
  print("\nFile not found.")
# Out:
# Study Notes Summary
# Total lines: 5
# Total words: 24
# Total characters: 157
#
# File read successfully.

# %% [markdown]
# ## Question 4 — Pandas Sales Data Analysis
#
# **30 points**
#
# You are helping a small café summarize its sales data.
#
# You are given the following data:
#
# ```python
# sales = [
#     {"item": "Latte", "category": "Drink", "price": 4.50, "quantity": 12},
#     {"item": "Muffin", "category": "Food", "price": 3.25, "quantity": 8},
#     {"item": "Tea", "category": "Drink", "price": 3.00, "quantity": 15},
#     {"item": "Bagel", "category": "Food", "price": 2.75, "quantity": 10},
#     {"item": "Smoothie", "category": "Drink", "price": 5.25, "quantity": 7}
# ]
# ```
#
# Write a Python program that:
#
# 1. Imports pandas as `pd`.
# 2. Converts the list of dictionaries into a DataFrame named `df`.
# 3. Creates a new column named `total_sales` by multiplying `price` by `quantity`.
# 4. Prints the first few rows of the DataFrame using `df.head()`.
# 5. Calculates and prints:
#
#    * total revenue, which is the sum of `total_sales`
#    * average item price using df["price"].mean()
#    * item with the highest `total_sales`
#    * total quantity sold by category
#
# For the item with the highest `total_sales`, you may use `idxmax()`.
#
# For total quantity sold by category, group the data by `category`.
#
# 6. Saves the DataFrame as:
#
# ```python
# sales_output.csv
# ```
#
# Use `index=False` when saving the CSV file.
#
# ### Grading — 30 points
#
# | Requirement                                             | Points |
# | ------------------------------------------------------- | -----: |
# | Imports pandas and creates DataFrame correctly          |      5 |
# | Creates `total_sales` column correctly                  |      6 |
# | Prints the first few rows using `df.head()`             |      3 |
# | Calculates total revenue correctly                      |      4 |
# | Calculates average item price correctly                 |      3 |
# | Finds the item with the highest `total_sales` correctly |      4 |
# | Calculates total quantity sold by category correctly    |      3 |
# | Saves CSV and code runs without errors                  |      2 |

# %%
# Question 4

sales = [
    {"item": "Latte", "category": "Drink", "price": 4.50, "quantity": 12},
    {"item": "Muffin", "category": "Food", "price": 3.25, "quantity": 8},
    {"item": "Tea", "category": "Drink", "price": 3.00, "quantity": 15},
    {"item": "Bagel", "category": "Food", "price": 2.75, "quantity": 10},
    {"item": "Smoothie", "category": "Drink", "price": 5.25, "quantity": 7}
]

import pandas as pd

df = pd.DataFrame(sales)

df["total_sales"] = df["price"] * df["quantity"]

print(df.head())

# calculating total revenue
total_revenue = df["total_sales"].sum()
print(f"Total revenue: ${total_revenue:.2f}")

# calculating average item price
average_item_price = df["price"].mean()
print(f"Average item price: ${average_item_price:.2f}")

# finding the item with the highest sales
highest_sales_item = df.loc[df["total_sales"].idxmax(), "item"]
print(f"Item with the highest sales: {highest_sales_item}")

# total quantity sold by category
total_quantity_by_category = df.groupby("category")["quantity"].sum()
print("Total quantity sold by category:")
print(total_quantity_by_category)

df.to_csv("sales_output.csv", index=False)
# Out:
#        item category  price  quantity  total_sales
# 0     Latte    Drink   4.50        12        54.00
# 1    Muffin     Food   3.25         8        26.00
# 2       Tea    Drink   3.00        15        45.00
# 3     Bagel     Food   2.75        10        27.50
# 4  Smoothie    Drink   5.25         7        36.75
# Total revenue: $189.25
# Average item price: $3.75
# Item with the highest sales: Latte
# Total quantity sold by category:
# category
# Drink    34
# Food     18
# Name: quantity, dtype: int64

# %% [markdown]
# ---
#
# ## End of Part 2
