# %% [markdown]
# <a href="https://colab.research.google.com/github/brooklynnsudler-collab/BrooklynnSudler_DTSC3020_Summer2026/blob/main/Copy_of_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1
#
# **Course:** DTSC 3020 — Introduction to Computation with Python
# **Lesson:** 1 — Orientation, Introduction, and Setup
# **Points:** 50
#
#
# ## How to use this notebook
#
# 1. Read each **question** (markdown cell) carefully.
# 2. Write your answer in the **code cell** that follows it.
# 3. Run the cell with `Shift + Enter` to see the output.
# 4. If you get an error, read the message, fix the code, and run it again.
#
#
# ---
# ## How to submit
#
# *You will submit by pushing this notebook to your GitHub account and then pasting the GitHub link in Canvas.*
# In Colab, click **File → Save a copy in GitHub**. Once the notebook is showing on GitHub, click the address bar of your browser and copy the full URL. Paste the link in Canvas.

# %% [markdown]
# ## Setup (run this first)
#
# Run the cell below to print a welcome message. If it prints successfully, your Colab environment is ready.

# %%
print("Environment is ready. Let's start Assignment 1!")
# Out:
# Environment is ready. Let's start Assignment 1!

# %% [markdown]
# ## Question 1 — Comments and `print()`  *(12 points)*
#
# In Lesson 1 we learned how to leave **comments** for humans (the computer ignores them) and how to display output with the **`print()`** function.
#
# ### What to do
# 1. On the **first line** of the code cell, write a **comment** (starts with `#`) that contains **your full name**.
# 2. On the **second line**, write another **comment** that says what this program does, for example: `# This program prints a few lines of text.`
# 3. Then use **three separate `print()` statements** to print exactly these three lines:
#
#    ```
#    Hello, world!
#    My name is <your name>.
#    I am learning Python in DTSC 3020.
#    ```
#
#    Replace `<your name>` with your real name (without the angle brackets).
#
# ### Hints
# - A comment line begins with the `#` symbol. Python ignores everything after `#` on that line.
# - Each `print("...")` puts its text on its own line.
# - Text inside `print()` must be wrapped in quotes: `print("Hello, world!")`.

# %%
# Brooklynn Sudler
# This program prints lines of text.
print("Hello, world!")
print("My name is Brooklynn.")
print("I am learning Python in DTSC 3020.")
# Out:
# Hello, world!
# My name is Brooklynn.
# I am learning Python in DTSC 3020.

# %% [markdown]
# ## Question 2 — Variables and Assignment  *(13 points)*
#
# A **variable** is a name that stores a value. We create one with the **assignment operator** `=`, like `city = "Denton"`.
#
# ### What to do
# 1. Create **three variables** and assign each a value:
#    - `course` — set it to the text `"DTSC 3020"`
#    - `university` — set it to the text `"University of North Texas"`
#    - `lesson_number` — set it to the whole number `1`
# 2. Use `print()` to display each variable's value. You can print the variable directly, like `print(course)`.
# 3. Your output should look like this (three lines):
#
#    ```
#    DTSC 3020
#    University of North Texas
#    1
#    ```
#
# ### Hints
# - Text values go in quotes: `course = "DTSC 3020"`.
# - Whole numbers do **not** use quotes: `lesson_number = 1`.
# - To print a variable, put its **name** inside `print()` with **no quotes**: `print(course)` (writing `print("course")` would just print the word *course*).

# %%
course = "DTSC 3020"
university = "University of North Texas"
lesson_number = 1
print(course)
print(university)
print(lesson_number)
# Out:
# DTSC 3020
# University of North Texas
# 1

# %% [markdown]
# ## Question 3 — Statements and Printing a Sentence  *(13 points)*
#
# A **statement** is a single instruction Python runs. In this question you will store information in variables and then print a full sentence by passing several items to `print()`, separated by commas.
#
# > 💡 When you put commas inside `print(...)`, Python prints each item with a **space** between them. Example:
# >
# > ```python
# > first = "Ada"
# > print("Hello,", first)      # prints:  Hello, Ada
# > ```
#
# ### What to do
# 1. Create two variables:
#    - `first_name` — your first name (text)
#    - `hometown` — the town or city you are from (text)
# 2. Using a **single `print()` statement** with commas, print a sentence in this format:
#
#    ```
#    My name is <first_name> and I am from <hometown> .
#    ```
#
#    (It is fine if there is an extra space before the period — that is just how commas add spaces. We will learn neater ways to format text in a later lesson.)
#
# ### Hints
# - Mix plain text (in quotes) and variable names (no quotes) inside one `print()`, separated by commas:
#   `print("My name is", first_name, "and I am from", hometown, ".")`
# - Each item is separated by a comma; quotes go only around the fixed text pieces.

# %%
first_name = "Brooklynn"
hometown = "Allen, TX"
print("My name is", first_name, "and I am from", hometown,".")
# Out:
# My name is Brooklynn and I am from Allen, TX .

# %% [markdown]
# ## Question 4 — Indentation and Fixing Errors  *(12 points)*
#
# Python is strict about **indentation** (spaces at the start of a line). At the top level of a program, a line should **not** start with spaces — an unexpected indent causes an error.
#
# The code cell below contains **two `print` statements that are broken**:
# - The first line has an **extra space** at the beginning (an indentation error).
# - The second line is **missing the quotation marks** around its text.
#
# ### What to do
# 1. **Run** the cell first and read the error message Python gives you. *(This is part of learning — errors are normal!)*
# 2. **Fix both lines** so the cell runs cleanly and prints:
#
#    ```
#       Indentation matters in Python.
#    I fixed the errors myself.
#    ```
# 3. On the line **below** your fixed code, add a **comment** that briefly says what each mistake was (one short sentence is enough).
#
# ### Hints
# - Remove the leading space so the line starts at the far left.
# - Put quotes around the text that should be printed.
# - A comment starts with `#`.

# %%
# Fix the two lines below, then add your explanation comment underneath.

print("   Indentation matters in Python.")
print("I fixed the errors myself.")
# The first line of code had a space before the "print" function which stopped it from running so I removed it. The second line needed quotes around the text.
# I also added some spacing infront of the text on the first line in order to match the desired output.
# Out:
#    Indentation matters in Python.
# I fixed the errors myself.
